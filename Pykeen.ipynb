# %%
# !rm -rf /content/sample_data
# !python3 -m pip uninstall pykeen
# !python3 -m pip install pykeen
# Out:
# Found existing installation: pykeen 1.6.0
# Uninstalling pykeen-1.6.0:
#   Would remove:
#     /usr/local/bin/pykeen
#     /usr/local/lib/python3.7/dist-packages/pykeen-1.6.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/pykeen/*
# Proceed (y/n)? y
#   Successfully uninstalled pykeen-1.6.0
# ...
#   Using cached pykeen-1.6.0-py3-none-any.whl (494 kB)
# ...

# %%
from pykeen.pipeline import pipeline

results = pipeline(model='TransE', dataset='Nations')
hits_at_10 = results.metric_results
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 575148869.
# ...
# Training batches on cuda:   0%|          | 0/7 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Starting batch_size search for evaluation now...
# INFO:pykeen.evaluation.evaluator:Concluded batch_size search with batch_size=201.
# Evaluating on cuda:   0%|          | 0.00/201 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.07s seconds

# %%
dir(results.model)
# Out:
# ['T_destination',
#  '__abstractmethods__',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__docdata__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slotnames__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_apply',
#  '_backward_hooks',
#  '_buffers',
#  '_call_impl',
#  '_entity_ids',
#  '_forward_hooks',
#  '_forward_pre_hooks',
#  '_free_graph_and_cache',
#  '_get_backward_hooks',
#  '_get_name',
#  '_is_full_backward_hook',
#  '_load_from_state_dict',
#  '_load_state_dict_pre_hooks',
#  '_maybe_warn_non_full_backward_hook',
#  '_modules',
#  '_named_members',
# ...

# %%
#Predict all tails
predicted_tails_df = results.model.get_tail_prediction_df('netherlands',	'militaryalliance',triples_factory=results.training)
predicted_tails_df[0:14]
# Out:
#     tail_id   tail_label      score  in_training
# 9         9  netherlands  -6.223188        False
# 2         2        china  -8.521313        False
# 3         3         cuba  -8.663849        False
# 8         8       jordan  -8.804905        False
# 13       13         ussr  -8.970556        False
# 0         0       brazil  -9.058088        False
# 12       12          usa  -9.109369         True
# 10       10       poland  -9.478601        False
# 4         4        egypt  -9.579985        False
# 7         7       israel  -9.887867        False
# 6         6    indonesia  -9.893959        False
# 11       11           uk -10.009319         True
# 5         5        india -10.022150        False
# 1         1        burma -11.362558        False

# %% [markdown]
# ## Own dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import pathlib
#TRAIN_PATH = HERE.joinpath('train.txt')
from pathlib import Path
p = Path("/content/drive/MyDrive/train_l.txt")
q = Path("/content/drive/MyDrive/test_l.txt")
print(type(p))
# Out:
# <class 'pathlib.PosixPath'>

# %%
print(p)
# Out:
# /content/drive/MyDrive/train_l.txt

# %%
from pykeen.triples import TriplesFactory
from pykeen.pipeline import pipeline
from pykeen.datasets.nations import NATIONS_TRAIN_PATH, NATIONS_TEST_PATH
result = pipeline(
    training=p,
    testing=q,
    model='TransE',
    epochs=5,  # short epochs for testing - you should go higher
)
result.save_to_directory('doctests/test_pre_stratified_transe')
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 3944027399.
# ...
# Training batches on cuda:   0%|          | 0/1 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Starting batch_size search for evaluation now...
# INFO:pykeen.evaluation.evaluator:Concluded batch_size search with batch_size=3.
# Evaluating on cuda:   0%|          | 0.00/3.00 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.08s seconds

# %%
predicted_tails_df = result.model.get_tail_prediction_df('Liverpool','isA',triples_factory=result.training)
predicted_tails_df[0:5]
# Out:
#    tail_id tail_label      score  in_training
# 4        4  Liverpool  -6.325066        False
# 6        6       Mike -10.184274        False
# 7        7     Person -10.367965        False
# 1        1       City -10.511396         True
# 3        3     George -10.812323        False
